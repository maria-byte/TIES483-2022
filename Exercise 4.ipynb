# %% [markdown]
# # Exercise 4
# * Due: 3.2. at 14:00
# * Max points: 8

# %% [markdown]
# ## General rules
# * **Submit your answers by using Moodle.** The link is <a href="https://moodle.jyu.fi/mod/assign/view.php?id=685529&forceview=1">https://moodle.jyu.fi/mod/assign/view.php?id=685529&forceview=1</a>.
# * Name your file as *lastname_ex4.xxx*. If you have multiple files, use *lastname_ex4_1.xxx, lastname_ex4_2.xxx* etc.
# * **Remember to add comments to your answers and include also some testing part!**
# * You will get feedback about your answers about 1-2 week from the due date

# %% [markdown]
# ## Exercises
#
# For tasks 1-3, we study optimization problem
# $$
# \begin{align}
# \min \qquad & x_1^2+x_2^2 + x_1+2x_2\\
# \text{s.t.}\qquad &x_1+x_2=1\\
#     &x_1,x_2\in\mathbb R
# \end{align}
# $$
#
# 1. **(2 points)** Solve the problem using the penalty function method. Note that it is not sufficient to use a fixed value for $r$.
# 2. **(2 points)** Solve the problem (i.e., approximate the optimal solution) using the barrier function method. Note that you need to do something a bit clever.
# 3. **(2 points)** Solve the problem using projected gradient method. Compare the performance to the penalty function and barrier function methods. (**Lecture7**)
# 4. **(2 points)** Check the *necessary first order KKT conditions* for the solution that you found.(**Lecture8**)
